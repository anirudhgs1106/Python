# %%
set1={"Red","Blue","Orange"}
print(type(set1))
print(set1)
# Out:
# <class 'set'>
# {'Orange', 'Red', 'Blue'}

# %%
set2={"Yellow","Blue","Green","Saffron","Green"}
print(set2)
# Out:
# {'Saffron', 'Green', 'Blue', 'Yellow'}

# %%
set1.add("Black")
print(set1)
# Out:
# {'Orange', 'Black', 'Red', 'Blue'}

# %%
set2.update(set1)
print(set2)
# Out:
# {'Orange', 'Black', 'Red', 'Yellow', 'Saffron', 'Blue', 'Green'}

# %%
set3=set(("Ani","Anirudh","AniGS"))
print(set3)
# Out:
# {'Ani', 'Anirudh', 'AniGS'}

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
import pandas as pd
df=pd.read_csv('/pima-indians-diabetes.data.csv')
df.corr()
# Out:
#               6       148        72        35         0      33.6     0.627  \
# 6      1.000000  0.128846  0.141197 -0.082495 -0.072999  0.017518 -0.033927
# 148    0.128846  1.000000  0.152498  0.056381  0.332383  0.220955  0.136903
# 72     0.141197  0.152498  1.000000  0.207308  0.089098  0.281777  0.041180
# 35    -0.082495  0.056381  0.207308  1.000000  0.437974  0.392553  0.183498
# 0     -0.072999  0.332383  0.089098  0.437974  1.000000  0.198111  0.185579
# 33.6   0.017518  0.220955  0.281777  0.392553  0.198111  1.000000  0.140546
# 0.627 -0.033927  0.136903  0.041180  0.183498  0.185579  0.140546  1.000000
# 50     0.544018  0.262408  0.239571 -0.115873 -0.040942  0.035911  0.032738
# 1      0.221087  0.465856  0.064882  0.073265  0.131984  0.292695  0.173245
#
#              50         1
# 6      0.544018  0.221087
# 148    0.262408  0.465856
# 72     0.239571  0.064882
# 35    -0.115873  0.073265
# 0     -0.040942  0.131984
# 33.6   0.035911  0.292695
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/pima-indians-diabetes.data.csv')
df.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/pima-indians-diabetes.data.csv')
df.plot(kind='scatter', x='6', y='148')
plt.show()

# %%
import pandas as pd
a=pd.Series([10,20,30,40,50])
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
b=pd.Series([10,20,30,40,50],index=['a','b','c','d','e'])
print(b)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
c=pd.Series({'a':10,'b':20,'c':30}) #Keys are considered as Index
c
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
d=pd.Series({'a':100,'b':200,'c':300},index=['a','d','c','b'])
d
# Out:
# a    100.0
# d      NaN
# c    300.0
# b    200.0
# dtype: float64

# %% [markdown]
# Extracting elements

# %%
import pandas as pd
a=pd.Series([10,20,30,40,50,60,70,80,90])
b=a[3]
print(b)
c=a[:3]
print(c)
d=a[-3:]
print(d)
# Out:
# 40
# 0    10
# 1    20
# 2    30
# dtype: int64
# 6    70
# 7    80
# 8    90
# dtype: int64

# %% [markdown]
# Basic Mathematics opeartions on Series

# %%
import pandas as pd
a=pd.Series([10,20,30,40,50,60,70,80,90])
a+1
# Out:
# 0    11
# 1    21
# 2    31
# 3    41
# 4    51
# 5    61
# 6    71
# 7    81
# 8    91
# dtype: int64

# %%
b=pd.Series([1,2,3,4,5,6,7,8,9])
a+b
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# 5    66
# 6    77
# 7    88
# 8    99
# dtype: int64

# %%
a*2
# Out:
# 0     20
# 1     40
# 2     60
# 3     80
# 4    100
# 5    120
# 6    140
# 7    160
# 8    180
# dtype: int64

# %%
b/2
# Out:
# 0    0.5
# 1    1.0
# 2    1.5
# 3    2.0
# 4    2.5
# 5    3.0
# 6    3.5
# 7    4.0
# 8    4.5
# dtype: float64

# %%
a-b
# Out:
# 0     9
# 1    18
# 2    27
# 3    36
# 4    45
# 5    54
# 6    63
# 7    72
# 8    81
# dtype: int64

# %% [markdown]
# Panda Dataframe

# %%
import pandas as pd
a=pd.DataFrame({'Name':['Ani','Anirudh','Sagar','Radhika'],'Age':[19,20,34,23]})
a
# Out:
#       Name  Age
# 0      Ani   19
# 1  Anirudh   20
# 2    Sagar   34
# 3  Radhika   23

# %%
x=pd.read_csv('/content/iris.csv')
x
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
x.tail() #Give last 5 rows of file
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
x.head() #Give first 5 rows of file
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x.shape #total number of rows and column
# Out:
# (150, 5)

# %%
x.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# .iloc[] is used to extract row amnd columns with help of index

# %%
x.iloc[1:11,0:4] #[rows,colums]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 1            4.9          3.0           1.4          0.2
# 2            4.7          3.2           1.3          0.2
# 3            4.6          3.1           1.5          0.2
# 4            5.0          3.6           1.4          0.2
# 5            5.4          3.9           1.7          0.4
# 6            4.6          3.4           1.4          0.3
# 7            5.0          3.4           1.5          0.2
# 8            4.4          2.9           1.4          0.2
# 9            4.9          3.1           1.5          0.1
# 10           5.4          3.7           1.5          0.2

# %%
x.loc[10:20,('Sepal.Length','Sepal.Width')]
# Out:
#     Sepal.Length  Sepal.Width
# 10           5.4          3.7
# 11           4.8          3.4
# 12           4.8          3.0
# 13           4.3          3.0
# 14           5.8          4.0
# 15           5.7          4.4
# 16           5.4          3.9
# 17           5.1          3.5
# 18           5.7          3.8
# 19           5.1          3.8
# 20           5.4          3.4

# %%
#axis is set 1 to drop that particular columns
x.drop('Species',axis=1)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
#axis is set 0 to drop that particular row
x.drop([1,2,3,4,5],axis=0)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [145 rows x 5 columns]

# %%
x.mean()
# Out:
# <ipython-input-52-0707e5fa66a2>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x.mean()
# Sepal.Length       4.3
# Sepal.Width        2.0
# Petal.Length       1.0
# Petal.Width        0.1
# Species         setosa
# dtype: object

# %%
x.min()
# Out:
# Sepal.Length       4.3
# Sepal.Width        2.0
# Petal.Length       1.0
# Petal.Width        0.1
# Species         setosa
# dtype: object

# %%
x.median()
# Out:
# <ipython-input-54-d3078f3a103e>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x.median()
# Sepal.Length    5.80
# Sepal.Width     3.00
# Petal.Length    4.35
# Petal.Width     1.30
# dtype: float64

# %%
x.max()
# Out:
# Sepal.Length          7.9
# Sepal.Width           4.4
# Petal.Length          6.9
# Petal.Width           2.5
# Species         virginica
# dtype: object

# %%
x.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
def double(s):
  return s*2

# %%
x[['Sepal.Length','Petal.Length']].apply(double)
# Out:
#      Sepal.Length  Petal.Length
# 0            10.2           2.8
# 1             9.8           2.8
# 2             9.4           2.6
# 3             9.2           3.0
# 4            10.0           2.8
# ..            ...           ...
# 145          13.4          10.4
# 146          12.6          10.0
# 147          13.0          10.4
# 148          12.4          10.8
# 149          11.8          10.2
#
# [150 rows x 2 columns]

# %%
x['Species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species, dtype: int64

# %%
x.sort_values(by='Sepal.Length ')
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
lis1=["Ani","ECE",121]
print(lis1)
print(type(lis1))
# Out:
# ['Ani', 'ECE', 121]
# <class 'list'>

# %%
lis2=["Anirudh","Electronics",246]
lis3=lis1+lis2
print(lis3)
# Out:
# ['Ani', 'ECE', 121, 'Anirudh', 'Electronics', 246]

# %%
print(len(lis1))
print(len(lis2))
print(len(lis3))
# Out:
# 3
# 3
# 6

# %%
lis3.append("Communication")
print(lis3)
# Out:
# ['Ani', 'ECE', 121, 'Anirudh', 'Electronics', 246, 'Communication']

# %%
lis1.clear()
print(lis1)
# Out:
# []

# %%
lis4=[10,34,2,5,110,43]
lis4.sort()
print(lis4)
# Out:
# [2, 5, 10, 34, 43, 110]

# %%
a=list((1,2,3,4,"Anirudh"))
print(a)
# Out:
# [1, 2, 3, 4, 'Anirudh']

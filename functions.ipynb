# %%
def hello():
  print("Hello")
hello()
# Out:
# Hello

# %%
def sum():
  print("Sum: ",a+b)
a=int(input("Enter 1st number: "))
b=int(input("Enter 2nd number: "))
sum()
# Out:
# Enter 1st number: 11
# Enter 2nd number: 10
# Sum:  21

# %%
def sum():
  c=a+b
  return c
a=int(input("Enter 1st number: "))
b=int(input("Enter 2nd number: "))
d=sum()
print("Sum: ",d)
# Out:
# Enter 1st number: 12
# Enter 2nd number: 22
# Sum:  34

# %%
def sum(a,b):
  c=a+b
  #print("Sum: ",c)
  return c
a=int(input("Enter 1st number: "))
b=int(input("Enter 2nd number: "))
#sum(a,b)
d=sum(a,b)
print("Sum: ",d)
# Out:
# Enter 1st number: 110
# Enter 2nd number: 10
# Sum:  120

# %%
def add(*args):
  sum=0
  for i in args:
    sum+=i
  return sum
print(add(1,2,3,4,5))
# Out:
# 15

# %%
def greet(**kwargs):
  for key,value in kwargs.items():
    print(value,end=" ")
greet(name="Anirudh",USN="01FE21BEC085",Dept="ECE")
# if end=" " is used then it will print in different lines
# Out:
# Anirudh 01FE21BEC085 ECE

# %%
dic1={"Name":"Anirudh","Age":20,"Gender":"Male"}
print(type(dic1))
print(dic1)
# Out:
# <class 'dict'>
# {'Name': 'Anirudh', 'Age': 20, 'Gender': 'Male'}

# %%
dic2={"Name":"Ani","Age":20,"Gender":"Male","Year":2003,"Year":2023}
print(dic2)
# Out:
# {'Name': 'Ani', 'Age': 20, 'Gender': 'Male', 'Year': 2023}

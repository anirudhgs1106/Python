# %% [markdown]
# **Question 1**

# %%
a=int(input("Enter 1st number: "))
b=int(input("Enter 2nd number: "))
if a>b:
  diff=a-b
  print(diff)
elif a<b:
  diff=b-a
  print(diff)
else :
  print(0)
# Out:
# Enter 1st number: 10
# Enter 2nd number: 10
# 0

# %% [markdown]
# **Question 2**

# %%
a=int(input("Enter number: "))
even=a%2
if even==0:
  print(a,"is Even number")
else:
  print(a,"is Odd number")
# Out:
# Enter number: 3
# 3 is Odd number

# %% [markdown]
# **Question 3**

# %%
a=int(input("Enter radius: "))
r=a**3
vol=(4*3.14*r)/3
print("Volume of sphere is: ",vol)
# Out:
# Enter radius: 3
# Volume of sphere is:  113.04

# %% [markdown]
# **Question 4**

# %%
a=int(input("Enter age: "))
year=2023-a
print("You were born in",year)
# Out:
# Enter age: 20
# You were born in 2003

# %% [markdown]
# **Question 5**

# %%
name=input("Enter your initial name: ")
name1=input("Enter your middle name: ")
name2=input("Enter your last name: ")
name3=name+" "+name1+" "+name2
print("Full name:",name3)
# Out:
# Enter your initial name: Anirudh
# Enter your middle name: G
# Enter your last name: Savanur
# Full name: Anirudh G Savanur

# %%
a=int(input("Enter a number: "))
b="*"
for i in range (a,0,-2):
  print(b*i)
# Out:
# Enter a number: 5
# *****
# ***
# *

# %%
a=int(input("Enter a number: "))
for i in range(1,11,1):
  print(a,"x",i,"=",a*i)
# Out:
# Enter a number: 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
a=int(input("Enter a number: "))
b="*"
c=" "
for i in range(a):
  sp=c*(a-i-1)
  st=b*(2*i+1)
  print(sp+st)
# Out:
# Enter a number: 3
#   *
#  ***
# *****

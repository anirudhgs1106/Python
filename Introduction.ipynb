# %%
print("Hello World")
# Out:
# Hello World

# %%
name="Anirudh"
print(type(name))
# Out:
# <class 'str'>

# %%
a="Ani"
b=12
c=3j
d=2.5
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'complex'>
# <class 'float'>

# %%
a=3
b=2
sum=a+b
print("Sum of",a,"and",b,"is",sum)
# Out:
# Sum of 3 and 2 is 5

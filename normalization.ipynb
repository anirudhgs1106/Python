# %% [markdown]
# **Loading Data from file and normalization operation**

# %% [markdown]
# 1. Min-Max Method

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/cancer.csv')
df
# Out:
#      cancer  population
# 0         1         445
# 1         0         559
# 2         3         677
# 3         4         681
# 4         3         746
# ..      ...         ...
# 296     250       62931
# 297     267       63476
# 298     244       66676
# 299     248       74005
# 300     360       88456
#
# [301 rows x 2 columns]

# %%
column_name=df.columns.tolist()
print(column_name)
# Out:
# ['cancer', 'population']

# %%
min_range=0
max_range=1
min_value=df['population'].min()
max_value=df['population'].max()
df['population']=(df['population']-min_value)/(max_value-min_value)*(max_range-min_range)+min_range
print(df)
# Out:
#      cancer  population
# 0         1    0.000000
# 1         0    0.001295
# 2         3    0.002636
# 3         4    0.002681
# 4         3    0.003420
# ..      ...         ...
# 296     250    0.709979
# 297     267    0.716172
# 298     244    0.752531
# 299     248    0.835805
# 300     360    1.000000
#
# [301 rows x 2 columns]

# %% [markdown]
# *2. Z Score method*

# %%
df1=pd.read_csv('/content/housing-data.csv')
df1
# Out:
#            DATE  HOUSTNSA
# 0    1959-01-01      96.2
# 1    1959-02-01      99.0
# 2    1959-03-01     127.7
# 3    1959-04-01     150.8
# 4    1959-05-01     152.5
# ..          ...       ...
# 709  2018-02-01      89.7
# 710  2018-03-01     107.2
# 711  2018-04-01     117.5
# 712  2018-05-01     123.8
# 713  2018-06-01     111.5
#
# [714 rows x 2 columns]

# %%
column_name1=df1.columns.tolist()
print(column_name1)
# Out:
# ['DATE', 'HOUSTNSA']

# %%
mean=df1['HOUSTNSA'].mean()
std=df1['HOUSTNSA'].std()
df1['HOUSTNSA']=(df1['HOUSTNSA']-mean)/std
print(df1)
# Out:
#            DATE  HOUSTNSA
# 0    1959-01-01 -0.599136
# 1    1959-02-01 -0.526995
# 2    1959-03-01  0.212450
# 3    1959-04-01  0.807614
# 4    1959-05-01  0.851414
# ..          ...       ...
# 709  2018-02-01 -0.766607
# 710  2018-03-01 -0.315725
# 711  2018-04-01 -0.050349
# 712  2018-05-01  0.111968
# 713  2018-06-01 -0.204937
#
# [714 rows x 2 columns]

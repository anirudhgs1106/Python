# %%
tuple1=("Ani","ECE",121)
print(tuple1)
print(type(tuple1))
# Out:
# ('Ani', 'ECE', 121)
# <class 'tuple'>

# %%
tuple2=("Anirudh","Electronics",246)
tuple3=tuple1+tuple2
print(tuple3)
# Out:
# ('Ani', 'ECE', 121, 'Anirudh', 'Electronics', 246)

# %%
x=tuple3.index("Anirudh")
print(x)
# Out:
# 3

# %%
y=tuple3[-1]
print(y)
# Out:
# 246

# %%
z=tuple3.count("Anirudh")
print(z)
# Out:
# 1

# %%
a=list(tuple3)
print(type(a))
a.append("Communication")
print(a)
b=tuple(a)
print(type(b))
print(b)
# Out:
# <class 'list'>
# ['Ani', 'ECE', 121, 'Anirudh', 'Electronics', 246, 'Communication']
# <class 'tuple'>
# ('Ani', 'ECE', 121, 'Anirudh', 'Electronics', 246, 'Communication')

# %%
tuple4=tuple(("Ani",246,"Anirudh"))
print(tuple4)
tuple5=tuple4*2
print(tuple5)
# Out:
# ('Ani', 246, 'Anirudh')
# ('Ani', 246, 'Anirudh', 'Ani', 246, 'Anirudh')
